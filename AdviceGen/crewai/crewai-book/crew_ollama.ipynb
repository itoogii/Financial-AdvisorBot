# %%
from dotenv import load_dotenv
from crewai import LLM, Agent, Task, Crew
import os
import yaml


# model = "ollama/llama3.1:8b"
model = "ollama/gemma3:4b"
api_url = "http://localhost:11434"


llm = LLM(
    model=model,
    endpoint=api_url,
)

# %% [markdown]
# ### Loading tasks from yaml

# %%
files={
    'agents': 'config/agents.yaml',
    'tasks': 'config/tasks.yaml'
}

configs={}
for config_type, file_path in files.items():
    with open(file_path, 'r') as file:
        configs[config_type] = yaml.safe_load(file)

agents_config = configs['agents']
tasks_config = configs['tasks']

# %%
financial_advisor_agent = Agent(
    config=agents_config['financial_advisor_agent']
)
advisory_task = Task(
    config=tasks_config['advisory_task'],
    agent=financial_advisor_agent
)

# %%
crew = Crew(
    agents=[financial_advisor_agent],
    tasks=[advisory_task],
    verbose=True
)

# %%
result=crew.kickoff()
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 6378913f-58d0-4239-87db-ae608044b1be                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Expert financial advisor                                                                                │
# │                                                                                                                 │
# │  Task: Provide stock market investment advise                                                                   │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# /home/batto/AdvisorBot/AdviceGen/crewai/.venv/lib/python3.12/site-packages/rich/live.py:256: UserWarning: install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Expert financial advisor                                                                                │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Investing in the stock market—specifically in a company like Apple Inc. (AAPL)—involves detailed               │
# │  consideration of both fundamental and tactical factors. Here’s a strategic and tactical guide addressing both  │
# │  short-term and long-term investment perspectives for Apple Inc., with important considerations for market      │
# │  participants.                                                                                                  │
# │                                                                                                                 │
# │  **About Investing in Apple Inc. (AAPL)**                                                                       │
# │  Apple is a global technology leader, known for its innovative consumer electronics, software, and services.    │
# │  Its market capitalization, earnings growth, and resilient business model have made it a popular choice among   │
# │  both institutional and retail investors. However, as with any publicly traded company, AAPL’s stock price can  │
# │  be affected by a range of internal and external factors, making investment outcomes uncertain and subject to   │
# │  market risks.                                                                                                  │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### **Short-term Investment Perspective (Tactical)**                                                           │
# │                                                                                                                 │
# │  **1. Earnings Reports & Guidance:**                                                                            │
# │  - Apple’s quarterly earnings releases are key events that can cause significant stock price movements.         │
# │  Monitor the company’s revenue, earnings per share, and outlook—paying close attention to iPhone sales trends,  │
# │  services growth, and geographic performance.                                                                   │
# │  - Analyst estimates vs. reported results can lead to volatility; unexpected surprises (positive or negative)   │
# │  often move Apple’s share price sharply in the days surrounding reports.                                        │
# │                                                                                                                 │
# │  **2. Market Sentiment & Trends:**                                                                              │
# │  - Short-term trading is heavily influenced by sentiment. Track market news, product launches (e.g., new        │
# │  iPhones, wearables), and macroeconomic developments. For example, global supply chain disruptions or           │
# │  regulatory actions in China can impact Apple’s revenues and investor sentiment quickly.                        │
# │  - Watch technical indicators (moving averages, support and resistance levels, relative strength index) for     │
# │  potential trade entries or exit signals based on historical price behavior.                                    │
# │                                                                                                                 │
# │  **3. Events & Announcements:**                                                                                 │
# │  - Monitor scheduled events, such as Apple’s annual Worldwide Developers Conference (WWDC) and new product      │
# │  unveilings. These can influence short-term price action.                                                       │
# │  - Pay attention to broader tech sector trends and announcements from major suppliers (like semiconductor       │
# │  manufacturers) that impact Apple's hardware production.                                                        │
# │                                                                                                                 │
# │  **Risks to Watch:**                                                                                            │
# │  - Short-term investments are vulnerable to unexpected market swings, news shocks, or global events.            │
# │  Liquidity, volatility, and sudden changes in sentiment can quickly affect portfolio value.                     │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### **Long-term Investment Perspective (Strategic)**                                                           │
# │                                                                                                                 │
# │  **1. Business Fundamentals:**                                                                                  │
# │  - Apple stands out for its strong brand loyalty, diversified product and service offerings, high margins, and  │
# │  robust cash flows. Evaluate long-term growth in key areas: expanding service revenues (App Store, iCloud,      │
# │  Apple Music), growing install base, and potential new product categories (e.g., AR/VR, electric vehicles).     │
# │  - Consider Apple’s capital return policy (share buybacks, dividends). A consistent buyback strategy and        │
# │  dividend growth can add shareholder value over time.                                                           │
# │                                                                                                                 │
# │  **2. Competitive Landscape & Innovation:**                                                                     │
# │  - Stay informed about developments in global consumer electronics and digital services, and Apple’s responses  │
# │  to competition from other tech giants (like Samsung, Google, Amazon).                                          │
# │  - Assess Apple’s innovation pipeline and R&D investments—future product launches may shape its growth          │
# │  trajectory over many years.                                                                                    │
# │                                                                                                                 │
# │  **3. Macro Trends and Regulatory Factors:**                                                                    │
# │  - Global economic conditions, currency exchange rates, and regulatory changes (data privacy, antitrust         │
# │  investigations, international tariffs) can materially impact Apple’s long-term profitability.                  │
# │  - Be aware of changing consumer behaviors, technological evolution, and Apple’s ability to adapt to these      │
# │  shifts.                                                                                                        │
# │                                                                                                                 │
# │  **Risks to Watch:**                                                                                            │
# │  - Long-term investments are subject to market cycles, sector rotation, and company-specific risks.             │
# │  Overreliance on flagship products, regulatory challenges, or slowing innovation can impact Apple’s future      │
# │  performance.                                                                                                   │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### **Key Guidelines for Any Investment Horizon**                                                              │
# │                                                                                                                 │
# │  1. **Diversification:**                                                                                        │
# │  Avoid concentrating your portfolio too heavily in any single stock, even one as prominent as Apple.            │
# │  Diversification reduces risk.                                                                                  │
# │                                                                                                                 │
# │  2. **Risk Management:**                                                                                        │
# │  Establish your risk tolerance, set investment goals, and determine potential loss thresholds. Use stop-loss    │
# │  orders or position sizing to manage downside exposure if actively trading.                                     │
# │                                                                                                                 │
# │  3. **Continuous Review:**                                                                                      │
# │  Regularly review your investment theses, monitor Apple’s performance, and adjust your strategies according to  │
# │  changing market conditions, earnings reports, and macroeconomic developments.                                  │
# │                                                                                                                 │
# │  4. **Education & Patience:**                                                                                   │
# │  Stock investing, in the short or long term, requires continuous learning and emotional discipline. Avoid       │
# │  making decisions based solely on hype or fear.                                                                 │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### **What to Watch as an Investor in AAPL**                                                                   │
# │                                                                                                                 │
# │  - Quarterly earnings, especially revenue, unit sales, and margins.                                             │
# │  - New product cycles, services growth, and ecosystem development.                                              │
# │  - Company events (product launches, annual meetings, developer conferences).                                   │
# │  - Regulatory headlines, particularly in key markets.                                                           │
# │  - Broader tech sector sentiment and macroeconomic signals.                                                     │
# │  - Apple’s capital allocation strategy (buybacks, dividend updates).                                            │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  **Conclusion:**                                                                                                │
# │  Investing in Apple Inc. offers exposure to a globally influential technology company with a track record of    │
# │  strong financial performance and innovation. For short-term investors, focus on catalyst events and technical  │
# │  signals while actively managing risk. For long-term investors, prioritize the company’s fundamentals,          │
# │  innovation roadmap, and macro trends, while maintaining a diversified investment portfolio.                    │
# │                                                                                                                 │
# │  No investment is without risk. Always align your investment approach with your financial goals, risk           │
# │  tolerance, and time horizon, and consider seeking personalized financial advice if needed.                     │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 7a7f9ba8-8bb6-497a-90e8-7d84be56386c                                                                     │
# │  Agent: Expert financial advisor                                                                                │
# │                                                                                                                 │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 6378913f-58d0-4239-87db-ae608044b1be                                                                       │
# │  Tool Args:                                                                                                     │
# │  Final Output: Investing in the stock market—specifically in a company like Apple Inc. (AAPL)—involves          │
# │  detailed consideration of both fundamental and tactical factors. Here’s a strategic and tactical guide         │
# │  addressing both short-term and long-term investment perspectives for Apple Inc., with important                │
# │  considerations for market participants.                                                                        │
# │                                                                                                                 │
# │  **About Investing in Apple Inc. (AAPL)**                                                                       │
# │  Apple is a global technology leader, known for its innovative consumer electronics, software, and services.    │
# │  Its market capitalization, earnings growth, and resilient business model have made it a popular choice among   │
# │  both institutional and retail investors. However, as with any publicly traded company, AAPL’s stock price can  │
# │  be affected by a range of internal and external factors, making investment outcomes uncertain and subject to   │
# │  market risks.                                                                                                  │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### **Short-term Investment Perspective (Tactical)**                                                           │
# │                                                                                                                 │
# │  **1. Earnings Reports & Guidance:**                                                                            │
# │  - Apple’s quarterly earnings releases are key events that can cause significant stock price movements.         │
# │  Monitor the company’s revenue, earnings per share, and outlook—paying close attention to iPhone sales trends,  │
# │  services growth, and geographic performance.                                                                   │
# │  - Analyst estimates vs. reported results can lead to volatility; unexpected surprises (positive or negative)   │
# │  often move Apple’s share price sharply in the days surrounding reports.                                        │
# │                                                                                                                 │
# │  **2. Market Sentiment & Trends:**                                                                              │
# │  - Short-term trading is heavily influenced by sentiment. Track market news, product launches (e.g., new        │
# │  iPhones, wearables), and macroeconomic developments. For example, global supply chain disruptions or           │
# │  regulatory actions in China can impact Apple’s revenues and investor sentiment quickly.                        │
# │  - Watch technical indicators (moving averages, support and resistance levels, relative strength index) for     │
# │  potential trade entries or exit signals based on historical price behavior.                                    │
# │                                                                                                                 │
# │  **3. Events & Announcements:**                                                                                 │
# │  - Monitor scheduled events, such as Apple’s annual Worldwide Developers Conference (WWDC) and new product      │
# │  unveilings. These can influence short-term price action.                                                       │
# │  - Pay attention to broader tech sector trends and announcements from major suppliers (like semiconductor       │
# │  manufacturers) that impact Apple's hardware production.                                                        │
# │                                                                                                                 │
# │  **Risks to Watch:**                                                                                            │
# │  - Short-term investments are vulnerable to unexpected market swings, news shocks, or global events.            │
# │  Liquidity, volatility, and sudden changes in sentiment can quickly affect portfolio value.                     │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### **Long-term Investment Perspective (Strategic)**                                                           │
# │                                                                                                                 │
# │  **1. Business Fundamentals:**                                                                                  │
# │  - Apple stands out for its strong brand loyalty, diversified product and service offerings, high margins, and  │
# │  robust cash flows. Evaluate long-term growth in key areas: expanding service revenues (App Store, iCloud,      │
# │  Apple Music), growing install base, and potential new product categories (e.g., AR/VR, electric vehicles).     │
# │  - Consider Apple’s capital return policy (share buybacks, dividends). A consistent buyback strategy and        │
# │  dividend growth can add shareholder value over time.                                                           │
# │                                                                                                                 │
# │  **2. Competitive Landscape & Innovation:**                                                                     │
# │  - Stay informed about developments in global consumer electronics and digital services, and Apple’s responses  │
# │  to competition from other tech giants (like Samsung, Google, Amazon).                                          │
# │  - Assess Apple’s innovation pipeline and R&D investments—future product launches may shape its growth          │
# │  trajectory over many years.                                                                                    │
# │                                                                                                                 │
# │  **3. Macro Trends and Regulatory Factors:**                                                                    │
# │  - Global economic conditions, currency exchange rates, and regulatory changes (data privacy, antitrust         │
# │  investigations, international tariffs) can materially impact Apple’s long-term profitability.                  │
# │  - Be aware of changing consumer behaviors, technological evolution, and Apple’s ability to adapt to these      │
# │  shifts.                                                                                                        │
# │                                                                                                                 │
# │  **Risks to Watch:**                                                                                            │
# │  - Long-term investments are subject to market cycles, sector rotation, and company-specific risks.             │
# │  Overreliance on flagship products, regulatory challenges, or slowing innovation can impact Apple’s future      │
# │  performance.                                                                                                   │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### **Key Guidelines for Any Investment Horizon**                                                              │
# │                                                                                                                 │
# │  1. **Diversification:**                                                                                        │
# │  Avoid concentrating your portfolio too heavily in any single stock, even one as prominent as Apple.            │
# │  Diversification reduces risk.                                                                                  │
# │                                                                                                                 │
# │  2. **Risk Management:**                                                                                        │
# │  Establish your risk tolerance, set investment goals, and determine potential loss thresholds. Use stop-loss    │
# │  orders or position sizing to manage downside exposure if actively trading.                                     │
# │                                                                                                                 │
# │  3. **Continuous Review:**                                                                                      │
# │  Regularly review your investment theses, monitor Apple’s performance, and adjust your strategies according to  │
# │  changing market conditions, earnings reports, and macroeconomic developments.                                  │
# │                                                                                                                 │
# │  4. **Education & Patience:**                                                                                   │
# │  Stock investing, in the short or long term, requires continuous learning and emotional discipline. Avoid       │
# │  making decisions based solely on hype or fear.                                                                 │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### **What to Watch as an Investor in AAPL**                                                                   │
# │                                                                                                                 │
# │  - Quarterly earnings, especially revenue, unit sales, and margins.                                             │
# │  - New product cycles, services growth, and ecosystem development.                                              │
# │  - Company events (product launches, annual meetings, developer conferences).                                   │
# │  - Regulatory headlines, particularly in key markets.                                                           │
# │  - Broader tech sector sentiment and macroeconomic signals.                                                     │
# │  - Apple’s capital allocation strategy (buybacks, dividend updates).                                            │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  **Conclusion:**                                                                                                │
# │  Investing in Apple Inc. offers exposure to a globally influential technology company with a track record of    │
# │  strong financial performance and innovation. For short-term investors, focus on catalyst events and technical  │
# │  signals while actively managing risk. For long-term investors, prioritize the company’s fundamentals,          │
# │  innovation roadmap, and macro trends, while maintaining a diversified investment portfolio.                    │
# │                                                                                                                 │
# │  No investment is without risk. Always align your investment approach with your financial goals, risk           │
# │  tolerance, and time horizon, and consider seeking personalized financial advice if needed.                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Tracing Status ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing is disabled.                                                                                     │
# │                                                                                                                 │
# │  To enable tracing, do any one of these:                                                                        │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
